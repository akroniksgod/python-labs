# %% [markdown]
# # Лабораторная работа №1

# %% [markdown]
# Описать структуру Московского зоопарка при помощи
# встроенных типов и структур данных.

# %%
KEY_TO_FIND = 'Манул'

left_side: dict = {
    'Викунья': ['Викунья'],
    'Капибара': ['Капибара'],
    'Гигантский муравьед': [],

    'Японский макак': ['Японский макак'],

    'Голубой Фазан': ['Обыкновенный фазан'],

    'Песец': ['Песец'],
    'Врановые': ['Ворон', 'Кафрский Рогатый ворон'],
    'Лесная куница': ['Лесная куница'],
    'Ночной мир': [
        'Ушастый ёж',
        'Белогрудый ёж',
        'Лесная соня',
        'Зелёная жаба',
        'Щетинохвостый кенгуру',
        'Жаба-ага',
        'Мохноногий сыч',
        'Карликовая сумчатая летяга',
        'Очковый листонос',
        'Кинкажу',
        'Летяга',
        'Мышь-малютка',
        'Нильский крылан',
        'Соня-полчок',
        'Африканская соня',
        'Карликовый летучий кускус',
        'Обыкновенная сипуха',
        'Дегу',
        'Иглистая мышь',
        'Шиншила',
    ],
    'Фауна России': [
        'Белогрудый ёж',
        'Неясыть',
        'Гривистый волк',
        'Полярный волк',
        'Красный волк',
        'Дальневосточный лесной кот',
    ],
    'Волк': ['Волк'],

    'Серый тюлень': ['Серый тюлень'],
    'Птица-секретарь': ['Секретарь'],
    'Райская красавка': ['Журавль-красавка'],
    'Хищные птицы': [
        'Андский кондор',
        'Белоголовый орлан',
        'Орлан-белохвост',
        'Степной орел',
        'Беркут',
        'Черный гриф',
        'Белоголовый гриф',
        'Белоголовый сип',
        'Белоплечий орлан',
        'Снежный гриф',
        'Орел-могильник',
    ],
    'Сурок': ['Степной сурок'],
    'Рептилии': [
        'Ядозуб',
        'Рогатая игуана',
        'Рогатая ящерица',
        'Большой сирен',
        'Эластичная черепаха',
        'Паук-птицеед',
        'Шлемоносный василиск',
    ],
    'Ящерицы': ['Исполинская ящерица', 'Рогатая ящерица'],
    
    'Слон': ['Азиатский слон', 'Даман брюса'],
    
    'Амфибии': [
        'Веслоног денниси',
        'Красноглазая квакша',
        'Дальневосточная квакша',
        'Голубой древолаз',
        'Жаба-ага',
        'Африкансий водонос (роющая лягушка)',
    ],
    
    'Попугаи': [
        'Сливоголовый попугай',
        'Даман брюса',
        'Орлиный попугай',
        'Сенегальский длиннокрылый попугай',
        'Попугай сине-жёлтый ара',
        'Патагонский земляной попугай',
        'Попугай жако',
        'Индийский кольчатый (ожереловый попугай)',
        'Волнистый попугайчик',
        'Благородный зелёно-красный попугай',
    ],
    'Казуар': ['Шлемоносный казуар'],
    'Пингвин': ['Пингвин гумбольдта'],
    'Дом птиц': [
        'Сорока',
        'Какаду гоффина',
        'Тукан',
        'Александрийский попугай',
        'Желтолобый амазон',
        'Веероносный венценосный голубь',
        'Двуцветный плодоядный голубь',
        'Гвинейский турако',
        'Балийский скворец',
        'Никобарский голубь',
        'Фиолетовый турако',
        'Голубая сорока',
        'Кулик-сорока',
        'Большой белый какаду',
        'Венесуэльский амазон',
        'Розовый какаду',
        'Большой тукан',
        'Черногребенчатый голубь',
        'Турако ливингстона (длиннохохлый турако)',
        'Благородный зелёно-красный попугай',
    ],
    'Кафрский рогатый ворон': [],
    'Чёрный аист': ['Чёрный аист'],
    
    'Северный морской котик': ['Северный морской котик'],
    'Сивуч': ['Сивуч'],
    'Ластоногие': [
        'Серый тюлень',
        'Морской заяц',
        'Морж',
        'Сивуч',
        'Северный морской котик',
    ],
    'Балтийский серый тюлень': [],
    'Морж': ['Морж'],
    
    'Чёрный лебедь': ['Чёрный лебедь'],
    'Овцебык': ['Канадский овцебык'],
    'Утки': [
        'Каролинская утка (каролинка)',
        'Кубинская свистящая утка',
        'Чирок (речная утка)',
        'Серая утка',
    ],
    
    'Лесной северный олень': [],
    'Равнинный тапир': ['Тапир'],
    
    'Орлан-белохвост': ['Орлан-белохвост'],
    'Андский кондор': ['Андский кондор'],
    'Скала хищных птиц': ['Андский кондор'],
    
    'Кустарниковая собака': ['Кустарниковая собака'],
    'Енот-полоскун': ['Енот-полоскун'],
    'Домашний як': [],
    
    'Гривистый волк': ['Гривистый волк'],
    'Пума': ['Пума'],
    'Кошачий ряд': [
        'Дальневосточный леопард',
        'Восточно-сибирская рысь',
        'Леопард дымчатый',
    ],
    'Дальневосточный леопард': ['Дальневосточный леопард'],
    'Рысь': ['Восточно-сибирская рысь'],
    'Гималайский медведь': ['Уссурийский белогрудый (гималайский) медведь'],
    KEY_TO_FIND: ['Манул'],
    'Беркут': ['Беркут'],
    'Малая панда': ['Малая панда'],
    'Большая панда': ['Большая панда'],
    
    'Обыкновенная носуха': ['Носуха'],
    'Красный волк': ['Красный волк'],
    
    'Совы': [
        'Обыкновенная неясыть',
        'Бородатая неясыть',
        'Болотная сова',
        'Белая сова',
        'Ушастая сова',
        'Длинная неясыть',
        'Неясыть',
        'Полярная сова',
    ],
    'Арахноландия': [
        'Паук-скакунчик',
        'Аранеоморфный паук',
        'Паук-птицеед',
        'Гигантский паук-краб',
        'Паук блуждающий',
        'Паук-серебрянка',
        'Паук-сенокосец',
        'Паук-рыболов (анцилометес)',
        'Фрины (жгутоногие пауки)',
        'Паук-аргиопа',
    ],
    
    'Ядовитые змеи': [],
    
    'Фламинго': [
        'Фламинго',
        'Красный фламинго',
        'Розовый фламинго',
    ],
    'Павлин': [
        'Обыкновенный павлин',
        'Павлин',
    ],
    
    'Гуси': [
        'Нильский гусь',
        'Гусь-белошей',
        'Серый гусь',
        'Горный гусь',
    ],
}

right_side: dict = {
    'Двупалый ленивец': ['Двупалый ленивец'],
    'Кенгуру Беннета': ['Кенгуру Беннета'],
    'Обыкновенная выдра': ['Обыкновенная выдра'],
    'Синантропные птицы': ['Никобарский голубь'],
    'Белая сова': ['Белая сова'],
    'Белый медведь': ['Белый медведь'],
    'Полярный мир': ['Белый медведь', 'Белая сова'],
    'Орёл': ['Степной орёл'],
    'Росомаха': ['Росомаха'],
    
    'Лебедь': [
        'Черношейный лебедь',
        'Чёрный лебедь',
        'Лебедь тундровый малый',
        'Малый (тундровый) лебедь',
        'Лебедь-шипун',
    ],
    'Земляная утка': ['Пеганка'],
    
    'Горный козел': [],
    'Винторогий козёл': ['Таджикский винтрогий козёл (мархур)'],
    'Тур': ['Дагестанский тур'],
    
    'Пеликан': [
        'Большой баклан',
        'Розовый пеликан',
        'Кудрявый пеликан',
    ],
    
    'Чирки Евразии': [
        'Мраморный чирок',
        'Лайсанский чирок (лайсанская кряква)',
        'Чирок-трескунок',
        'Чирок-клоктун',
        'Кольчатый чирок',
        'Чирок (речная утка)',
        'Чирок-свистунок',
    ],
    'Птицы и бабочки тропиков': [
        'Совинная бабочка',
        'Розовая колпица',
        'Бабочка parthenos sylvia',
        'Обыкновенная колпица',
        'Бабочка идея левконоя',
        'Бабочка калиго',
    ],
    'Цапля': [
        'Цапля египетская',
        'Цапля жёлтая',
        'Серая цапля',
        'Египетская цапля',
        'Большая белая цапля',
        'Бабочка калиго',
    ],
    
    'Копытные': [
        'Двугорбый верблюд',
        'Сычуаньский такин',
    ],
    
    'Шакал': [
        'Обыкновенный шакал',
        'Южноевропейский шакал',
    ],
    'Бурый медведь': ['Бурый медведь'],
    'Азиатский лев': ['Индийский лев'],
    'Полосатая гиена': ['Полосатая гиена'],
    'Полярный волк': ['Полярный волк'],
    'Рыбы коралловых рифов': [
        'Коралловый аспид',
        'Мягкие кораллы',
        'Красный коралловый групер',
    ],
    'Экзотариум': [
        'Четырехцветная актиния',
        'Акулы',
        'Мурена-зебра',
        'Ленточная мурена',
        'Мурена-ехидна звездчатая',
        'Сотовая мурена',
        'Групер горбатый',
    ],
    
    'Животные Африки': [
        'Сурикат',
        'Карликовый бегемот',
        'Медоед',
        'Зебра греви',
        'Южноафриканский жираф',
    ],
    'Чёрная антилопа': ['Южноафриканская чёрная антилопа'],
    
    'Конюшня': [
        'Ахалтекинская лошадь',
        'Лошадь домашняя',
        'Эстонская местная лошадь',
        'Аппалуза пони',
        'Английская чистокровная лошадь',
    ],
   
    'Дом приматов': [
        'Эдипов тамарин',
        'Буроголовый тамарин',
        'Краснорукий тамарин',
        'Золотистыйы львиный тамарин',
        'Боливийская мирикина',
    ],
    
    'Террариум': [
        'Гавиаловый крокодил',
        'Китайский аллигатор',
        'Тёмный тигровый питон',
        'Чёрный кайман',
        'Тупорылый крокодил',
        'Сетчатый питон',
        'Сиамский крокодил',
        'Нильский крокодил',
        'Парагвайская анаконда',
        'Гладколобый кайман',
    ],
    
    'Корова': [],
    'Камерунская коза': [],
    'Валлийская черноносая овца': ['Валлийская черноносая овца'],
    'Домашняя цесарка': ['Обыкновенная цесарка'],
    'Птичий коридор': [],
    'Кролик': ['Кролик'],
}

zoo: dict = {
    **left_side,
    **right_side,
}

# %%
elements_delimiter = ', '
last_element_delimiter = ';'
for aviary, animals in zoo.items():
    contains_animals = len(animals) > 0
    aviary_animals = '' if contains_animals else last_element_delimiter
    if contains_animals:
        last_aviary_animal = animals[-1]
        for animal in animals:
            is_last_element = animal == last_aviary_animal
            delimiter = last_element_delimiter if is_last_element else elements_delimiter
            aviary_animals = aviary_animals + str(animal) + delimiter
    
    print(f'\t- {aviary}: {aviary_animals}\n')
# Out:
# 	- Викунья: Викунья;
#
# 	- Капибара: Капибара;
#
# 	- Гигантский муравьед: ;
#
# 	- Японский макак: Японский макак;
#
# 	- Голубой Фазан: Обыкновенный фазан;
#
# 	- Песец: Песец;
#
# 	- Врановые: Ворон, Кафрский Рогатый ворон;
#
# 	- Лесная куница: Лесная куница;
#
# 	- Ночной мир: Ушастый ёж, Белогрудый ёж, Лесная соня, Зелёная жаба, Щетинохвостый кенгуру, Жаба-ага, Мохноногий сыч, Карликовая сумчатая летяга, Очковый листонос, Кинкажу, Летяга, Мышь-малютка, Нильский крылан, Соня-полчок, Африканская соня, Карликовый летучий кускус, Обыкновенная сипуха, Дегу, Иглистая мышь, Шиншила;
#
# 	- Фауна России: Белогрудый ёж, Неясыть, Гривистый волк, Полярный волк, Красный волк, Дальневосточный лесной кот;
#
# 	- Волк: Волк;
#
# 	- Серый тюлень: Серый тюлень;
#
# 	- Птица-секретарь: Секретарь;
#
# 	- Райская красавка: Журавль-красавка;
#
# ...

# %% [markdown]
# Написать код, который возвращает соседей манула Тимофея
# (т.е. просто соседние с манулами вольеры)

# %%
NEIGHBOURS_KEYS = [
    'Рысь',
    'Гималайский медведь',
    'Беркут',
    'Малая панда',
    'Большая панда',
]

# %%
print("Соседи манула")
for aviary, animals in zoo.items():
    is_neighbour = NEIGHBOURS_KEYS.count(aviary) > 0
    if not is_neighbour:
        continue
    
    contains_animals = len(animals) > 0
    aviary_animals = '' if contains_animals else last_element_delimiter
    if contains_animals:
        last_aviary_animal = animals[-1]
        for animal in animals:
            is_last_element = animal == last_aviary_animal
            delimiter = last_element_delimiter if is_last_element else elements_delimiter
            aviary_animals = aviary_animals + str(animal) + delimiter
    
    print(f'\t- {aviary}: {aviary_animals}\n')
# Out:
# Соседи манула
# 	- Рысь: Восточно-сибирская рысь;
#
# 	- Гималайский медведь: Уссурийский белогрудый (гималайский) медведь;
#
# 	- Беркут: Беркут;
#
# 	- Малая панда: Малая панда;
#
# 	- Большая панда: Большая панда;
